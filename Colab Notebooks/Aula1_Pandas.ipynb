# %%
print (1+1)
# Out:
# 2

# %%
print (1+1)
# Out:
# 2

# %%
#importando a biblioteca pandas
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/Datasets/gapminder.csv")

# %%
#Visualizando as 5 primeiras linhas

# %%
df.head()
# Out:
#    geo  time  ...  working_hours_per_week  yearly_co2_emissions_1000_tonnes
# 0  afg  1700  ...                     NaN                               NaN
# 1  afg  1800  ...                     NaN                               NaN
# 2  afg  1801  ...                     NaN                               NaN
# 3  afg  1802  ...                     NaN                               NaN
# 4  afg  1803  ...                     NaN                               NaN
#
# [5 rows x 537 columns]

# %%
df = pd.read_csv("/content/drive/MyDrive/Datasets/gapminder.csv", sep=",")

# %%
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
df.rename(columns={"country":"Pais","continent":"Continente","year":"Ano","lifeExp":"Expectativa de vida","pop":"Populacao total","gdpPercap":"PIB per capita"})
# Out:
#              Pais Continente  ...  Populacao total  PIB per capita
# 0     Afghanistan       Asia  ...          8425333      779.445314
# 1     Afghanistan       Asia  ...          9240934      820.853030
# 2     Afghanistan       Asia  ...         10267083      853.100710
# 3     Afghanistan       Asia  ...         11537966      836.197138
# 4     Afghanistan       Asia  ...         13079460      739.981106
# ...           ...        ...  ...              ...             ...
# 1699     Zimbabwe     Africa  ...          9216418      706.157306
# 1700     Zimbabwe     Africa  ...         10704340      693.420786
# 1701     Zimbabwe     Africa  ...         11404948      792.449960
# 1702     Zimbabwe     Africa  ...         11926563      672.038623
# 1703     Zimbabwe     Africa  ...         12311143      469.709298
#
# [1704 rows x 6 columns]

# %%
df.read(10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-23a29e90b0e0> in <module>()
# ----> 1 df.read(10)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5139             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5140                 return self[name]
# -> 5141             return object.__getattribute__(self, name)
#    5142
#    5143     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'read'

# %%
df.hear(10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-7db902e4e796> in <module>()
# ----> 1 df.hear(10)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5139             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5140                 return self[name]
# -> 5141             return object.__getattribute__(self, name)
#    5142
#    5143     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'hear'

# %%
df.head(10)
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106
# 5  Afghanistan      Asia  1977   38.438  14880372  786.113360
# 6  Afghanistan      Asia  1982   39.854  12881816  978.011439
# 7  Afghanistan      Asia  1987   40.822  13867957  852.395945
# 8  Afghanistan      Asia  1992   41.674  16317921  649.341395
# 9  Afghanistan      Asia  1997   41.763  22227415  635.341351

# %%
df.shape
# Out:
# (1704, 6)

# %%
df.columns
# Out:
# Index(['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap'], dtype='object')

# %%
df.rename(columns={"country":"Pais","continent":"Continente","year":"Ano","lifeExp":"Expectativa de vida","pop":"Populacao total","gdpPercap":"PIB per capita"})
# Out:
#              Pais Continente  ...  Populacao total  PIB per capita
# 0     Afghanistan       Asia  ...          8425333      779.445314
# 1     Afghanistan       Asia  ...          9240934      820.853030
# 2     Afghanistan       Asia  ...         10267083      853.100710
# 3     Afghanistan       Asia  ...         11537966      836.197138
# 4     Afghanistan       Asia  ...         13079460      739.981106
# ...           ...        ...  ...              ...             ...
# 1699     Zimbabwe     Africa  ...          9216418      706.157306
# 1700     Zimbabwe     Africa  ...         10704340      693.420786
# 1701     Zimbabwe     Africa  ...         11404948      792.449960
# 1702     Zimbabwe     Africa  ...         11926563      672.038623
# 1703     Zimbabwe     Africa  ...         12311143      469.709298
#
# [1704 rows x 6 columns]

# %%
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
df=df.rename(columns={"country":"Pais","continent":"Continente","year":"Ano","lifeExp":"Expectativa de vida","pop":"Populacao total","gdpPercap":"PIB per capita"})

# %%
df.head()
# Out:
#           Pais Continente  ...  Populacao total  PIB per capita
# 0  Afghanistan       Asia  ...          8425333      779.445314
# 1  Afghanistan       Asia  ...          9240934      820.853030
# 2  Afghanistan       Asia  ...         10267083      853.100710
# 3  Afghanistan       Asia  ...         11537966      836.197138
# 4  Afghanistan       Asia  ...         13079460      739.981106
#
# [5 rows x 6 columns]

# %%
df.dtypes
# Out:
# Pais                    object
# Continente              object
# Ano                      int64
# Expectativa de vida    float64
# Populacao total          int64
# PIB per capita         float64
# dtype: object

# %%
df.tail()
# Out:
#           Pais Continente  ...  Populacao total  PIB per capita
# 1699  Zimbabwe     Africa  ...          9216418      706.157306
# 1700  Zimbabwe     Africa  ...         10704340      693.420786
# 1701  Zimbabwe     Africa  ...         11404948      792.449960
# 1702  Zimbabwe     Africa  ...         11926563      672.038623
# 1703  Zimbabwe     Africa  ...         12311143      469.709298
#
# [5 rows x 6 columns]

# %%
df.describe()
# Out:
#               Ano  Expectativa de vida  Populacao total  PIB per capita
# count  1704.00000          1704.000000     1.704000e+03     1704.000000
# mean   1979.50000            59.474439     2.960121e+07     7215.327081
# std      17.26533            12.917107     1.061579e+08     9857.454543
# min    1952.00000            23.599000     6.001100e+04      241.165877
# 25%    1965.75000            48.198000     2.793664e+06     1202.060309
# 50%    1979.50000            60.712500     7.023596e+06     3531.846989
# 75%    1993.25000            70.845500     1.958522e+07     9325.462346
# max    2007.00000            82.603000     1.318683e+09   113523.132900

# %%
df["Continente"].unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'Americas', 'Oceania'], dtype=object)

# %%
Oceania = df.loc[df["Continente"]=="Oceania"]

# %%
Oceania.head()
# Out:
#          Pais Continente  ...  Populacao total  PIB per capita
# 60  Australia    Oceania  ...          8691212     10039.59564
# 61  Australia    Oceania  ...          9712569     10949.64959
# 62  Australia    Oceania  ...         10794968     12217.22686
# 63  Australia    Oceania  ...         11872264     14526.12465
# 64  Australia    Oceania  ...         13177000     16788.62948
#
# [5 rows x 6 columns]

# %%
Oceania["Continente"].unique()
# Out:
# array(['Oceania'], dtype=object)

# %%
df.groupby("Continente")["Pais"].nunique()
# Out:
# Continente
# Africa      52
# Americas    25
# Asia        33
# Europe      30
# Oceania      2
# Name: Pais, dtype: int64

# %%
df.groupby("Ano")["Expectativa de vida"].mean()
# Out:
# Ano
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: Expectativa de vida, dtype: float64

# %%
df["PIB per capita"].mean()
# Out:
# 7215.327081211966

# %%
df["PIB per capita"].sum()
# Out:
# 12294917.3463852
